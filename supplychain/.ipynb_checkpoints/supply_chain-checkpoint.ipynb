# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('supply_chain_data.csv')

# %%
df.head()
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006            55                      802
# 1     skincare  SKU1  14.843523            95                      736
# 2     haircare  SKU2  11.319683            34                        8
# 3     skincare  SKU3  61.163343            68                       83
# 4     skincare  SKU4   4.805496            26                      871
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# 1        7460.900065                Female            53          30
# 2        9577.749626               Unknown             1          10
# 3        7766.836426            Non-binary            23          13
# 4        2686.505152            Non-binary             5           3
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# 0                96  ...    Mumbai        29                 215
# 1                37  ...    Mumbai        23                 517
# 2                88  ...    Mumbai        12                 971
# 3                59  ...   Kolkata        24                 937
# 4                56  ...     Delhi         5                 414
#
#   Manufacturing lead time Manufacturing costs  Inspection results  \
# 0                      29           46.279879             Pending
# 1                      30           33.616769             Pending
# 2                      27           30.688019             Pending
# 3                      18           35.624741                Fail
# 4                       3           92.065161                Fail
#
#    Defect rates  Transportation modes   Routes       Costs
# 0      0.226410                  Road  Route B  187.752075
# 1      4.854068                  Road  Route B  503.065579
# 2      4.580593                   Air  Route C  141.920282
# 3      4.746649                  Rail  Route A  254.776159
# 4      3.145580                   Air  Route A  923.440632
#
# [5 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Product type             100 non-null    object
#  1   SKU                      100 non-null    object
#  2   Price                    100 non-null    float64
#  3   Availability             100 non-null    int64
#  4   Number of products sold  100 non-null    int64
#  5   Revenue generated        100 non-null    float64
#  6   Customer demographics    100 non-null    object
#  7   Stock levels             100 non-null    int64
#  8   Lead times               100 non-null    int64
#  9   Order quantities         100 non-null    int64
#  10  Shipping times           100 non-null    int64
#  11  Shipping carriers        100 non-null    object
#  12  Shipping costs           100 non-null    float64
#  13  Supplier name            100 non-null    object
#  14  Location                 100 non-null    object
#  15  Lead time                100 non-null    int64
#  16  Production volumes       100 non-null    int64
#  17  Manufacturing lead time  100 non-null    int64
#  18  Manufacturing costs      100 non-null    float64
#  19  Inspection results       100 non-null    object
#  20  Defect rates             100 non-null    float64
#  21  Transportation modes     100 non-null    object
#  22  Routes                   100 non-null    object
#  23  Costs                    100 non-null    float64
# dtypes: float64(6), int64(9), object(9)
# memory usage: 18.9+ KB

# %%
df.isnull().sum()
# Out:
# Product type               0
# SKU                        0
# Price                      0
# Availability               0
# Number of products sold    0
# Revenue generated          0
# Customer demographics      0
# Stock levels               0
# Lead times                 0
# Order quantities           0
# Shipping times             0
# Shipping carriers          0
# Shipping costs             0
# Supplier name              0
# Location                   0
# Lead time                  0
# Production volumes         0
# Manufacturing lead time    0
# Manufacturing costs        0
# Inspection results         0
# Defect rates               0
# Transportation modes       0
# Routes                     0
# Costs                      0
# dtype: int64

# %%
df.nunique()
# Out:
# Product type                 3
# SKU                        100
# Price                      100
# Availability                63
# Number of products sold     96
# Revenue generated          100
# Customer demographics        4
# Stock levels                65
# Lead times                  29
# Order quantities            61
# Shipping times              10
# Shipping carriers            3
# Shipping costs             100
# Supplier name                5
# Location                     5
# Lead time                   29
# Production volumes          96
# Manufacturing lead time     30
# Manufacturing costs        100
# Inspection results           3
# Defect rates               100
# Transportation modes         4
# Routes                       3
# Costs                      100
# dtype: int64

# %%
df.drop('SKU', axis=1, inplace=True) #dropping unnecceesssary columns

# %%
df['Customer demographics'].unique() #identify types of genders
# Out:
# array(['Non-binary', 'Female', 'Unknown', 'Male'], dtype=object)

# %%
df['Customer demographics'] = df['Customer demographics'].replace('Unknown', 'others')

# %%
df.describe()
# Out:
#             Price  Availability  Number of products sold  Revenue generated  \
# count  100.000000    100.000000               100.000000         100.000000
# mean    49.462461     48.400000               460.990000        5776.048187
# std     31.168193     30.743317               303.780074        2732.841744
# min      1.699976      1.000000                 8.000000        1061.618523
# 25%     19.597823     22.750000               184.250000        2812.847151
# 50%     51.239831     43.500000               392.500000        6006.352023
# 75%     77.198228     75.000000               704.250000        8253.976921
# max     99.171329    100.000000               996.000000        9866.465458
#
#        Stock levels  Lead times  Order quantities  Shipping times  \
# count    100.000000  100.000000        100.000000      100.000000
# mean      47.770000   15.960000         49.220000        5.750000
# std       31.369372    8.785801         26.784429        2.724283
# min        0.000000    1.000000          1.000000        1.000000
# 25%       16.750000    8.000000         26.000000        3.750000
# 50%       47.500000   17.000000         52.000000        6.000000
# 75%       73.000000   24.000000         71.250000        8.000000
# max      100.000000   30.000000         96.000000       10.000000
#
#        Shipping costs   Lead time  Production volumes  \
# count      100.000000  100.000000          100.000000
# mean         5.548149   17.080000          567.840000
# std          2.651376    8.846251          263.046861
# min          1.013487    1.000000          104.000000
# 25%          3.540248   10.000000          352.000000
# 50%          5.320534   18.000000          568.500000
# 75%          7.601695   25.000000          797.000000
# max          9.929816   30.000000          985.000000
#
#        Manufacturing lead time  Manufacturing costs  Defect rates       Costs
# count                100.00000           100.000000    100.000000  100.000000
# mean                  14.77000            47.266693      2.277158  529.245782
# std                    8.91243            28.982841      1.461366  258.301696
# min                    1.00000             1.085069      0.018608  103.916248
# 25%                    7.00000            22.983299      1.009650  318.778455
# 50%                   14.00000            45.905622      2.141863  520.430444
# 75%                   23.00000            68.621026      3.563995  763.078231
# max                   30.00000            99.466109      4.939255  997.413450

# %%
df['Total shipping cost'] = df['Shipping costs'] + df['Costs'] #adding total cost columns for shipping charges.

# %%
df.head()
# Out:
#   Product type      Price  Availability  Number of products sold  \
# 0     haircare  69.808006            55                      802
# 1     skincare  14.843523            95                      736
# 2     haircare  11.319683            34                        8
# 3     skincare  61.163343            68                       83
# 4     skincare   4.805496            26                      871
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# 1        7460.900065                Female            53          30
# 2        9577.749626                others             1          10
# 3        7766.836426            Non-binary            23          13
# 4        2686.505152            Non-binary             5           3
#
#    Order quantities  Shipping times  ... Lead time  Production volumes  \
# 0                96               4  ...        29                 215
# 1                37               2  ...        23                 517
# 2                88               2  ...        12                 971
# 3                59               6  ...        24                 937
# 4                56               8  ...         5                 414
#
#   Manufacturing lead time Manufacturing costs  Inspection results  \
# 0                      29           46.279879             Pending
# 1                      30           33.616769             Pending
# 2                      27           30.688019             Pending
# 3                      18           35.624741                Fail
# 4                       3           92.065161                Fail
#
#    Defect rates  Transportation modes   Routes       Costs  \
# 0      0.226410                  Road  Route B  187.752075
# 1      4.854068                  Road  Route B  503.065579
# 2      4.580593                   Air  Route C  141.920282
# 3      4.746649                  Rail  Route A  254.776159
# 4      3.145580                   Air  Route A  923.440632
#
#    Total shipping cost
# 0           190.708648
# 1           512.782154
# 2           149.974761
# 3           256.505728
# 4           927.331180
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Product Analysis

# %%
# Most ordered products

most_ordered = df.groupby('Product type', as_index=False)['Number of products sold'].sum()
plt.pie(x='Number of products sold',data=most_ordered, labels='Product type', autopct='%1.1f%%')
plt.title('Distribution of no. of products sold')
plt.tight_layout
plt.show()

# %% [markdown]
# #### Skincare products are most popular among the customers followed by haircare & cosmetics.

# %%
# top selling product category
prod_type_rev = df.groupby(['Product type'], as_index=False)['Revenue generated'].sum()

sns.set(style='whitegrid')
sns.barplot(x='Product type', y='Revenue generated', data=prod_type_rev)
plt.title('Most Profitable Products')
plt.show()

# %% [markdown]
# #### Skincare products are proven to be most popular and most profitable product for the company. Haircare and Cosmetics generates low revenue comparatively.

# %%
# Average Manufacturnig cost for Products
product_cost = df.groupby('Product type', as_index=False)['Manufacturing costs'].mean()
sns.barplot(data=product_cost, x='Product type', y='Manufacturing costs')
plt.title('Average Manufacturing Costs')
plt.show()

# %% [markdown]
# #### Manufacturing cost is much higher for Haircare products as compared to its popularity and profitability. Skincare products are the costliest.

# %% [markdown]
# ### Customer Analysis

# %%
# sales by customer demographics
cust_dem = df.groupby('Customer demographics', as_index=False)['Revenue generated'].sum()
sns.barplot(data=cust_dem, y='Revenue generated', x='Customer demographics')
plt.title('Revenue generated by Demographics')
plt.show()

# %% [markdown]
# #### Others or and Female customers are spending the most generating most of the profits for the company. Non binary customers are spending the least.

# %%
# Product sales by Customers
sns.countplot(data=df, x='Customer demographics', hue='Product type', )
plt.title('Product category sales by Customer Demographics')
plt.show()

# %% [markdown]
# #### Most of our sales are driven by Other genders and Females. Others have purchased more Haircare products and Females have purchased more Skincare products. Skincare products are also popular among Non-binary customers.

# %% [markdown]
# ### Geographical Analysis

# %%
# Customers in each locations.
customer_counts_by_location = df['Location'].value_counts().reset_index()
customer_counts_by_location.columns = ['Location', 'Customer Count']
sns.barplot(data=customer_counts_by_location, x='Location', y='Customer Count')
plt.title('Customer Distribution by Location')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Large portion of customers resides in Kolkata followed by other locations. Delhi has the lowest number of customers.

# %%
sales_city = df.groupby(['Location', 'Product type'], as_index=False)['Number of products sold'].sum()

pivot_table = sales_city.pivot_table(index='Location', columns='Product type', values='Number of products sold')
pivot_table.plot(kind='bar', stacked=True)
plt.xlabel('Location')
plt.ylabel=('No. of products sold')
plt.title('No. of Products Sold by Location and Product type')
plt.show()

# %% [markdown]
# #### Large number of products were sold in Kolkata followed by Delhi and Mumbai. Banglore has the lowest number of products sold.

# %%
# Revenue generated by each city
rev_city = df.groupby('Location', as_index=False)['Revenue generated'].sum().sort_values(by='Revenue generated')
plt.figure(figsize=(8,5))
sns.barplot(data=rev_city, x='Revenue generated', y='Location')
plt.title('Sales generated by Locations')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Although most number of products were purchased by Kolkata, Mumbai has bought the costliest products followed by Kolkata and others.

# %%
# Shipping time by Location
sns.violinplot(x='Location', y='Shipping times', data=df)
plt.title('Shipping Time by Location')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Average shipping time for Banglore and Mumbai are the lowest hence fastest delivery. Kolkata has the highest average delivery time. Shipping to Delhi takes most time overall.

# %% [markdown]
# ### Supplier and Manufacturing Analysis

# %%
# largest suppliers
sns.countplot(data=df, x='Supplier name', palette='viridis')
plt.title('Supplier Distribution')
plt.show()

# %% [markdown]
# #### Supplier 1 is the top supplier to the company followed by Supplier 2 and others. Supplier 3 has the lowest production rate.

# %%
# Products Manufactured by suppliers
sns.countplot(data=df, x='Supplier name', hue='Product type', palette='viridis')
plt.title('Products manufacturing by Suppliers')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Apparently Supplier 1 who is the top supplier is manufcaturing most of the Skincare products which is the top selling product. Supplier 2 & Supplier 4 is manufacturing most of the Haircare products.

# %%
# Time to produce the products
manufacturing_time = df.groupby(['Supplier name','Product type'], as_index=False)['Manufacturing lead time'].mean()
sns.barplot(data=manufacturing_time, x='Supplier name', y='Manufacturing lead time', hue='Product type')
plt.title('Manufacturing Time for Products')
plt.show()

# %%
# Manufacturing cost by each supplier
supplier_cost = df.groupby('Supplier name', as_index=False)['Manufacturing costs'].mean()
sns.barplot(data=supplier_cost, x='Supplier name', y='Manufacturing costs')
plt.title('Average Manufacturing Cost by Supplier')
plt.show()

# %% [markdown]
# #### Supplier 2 and Supplier 1 has the loweest manufacturing cost and with the given production rate and the revenue their product is generating, they're the most cost effective suppliers for the company. Supplier 4 is manufacturing low amount of products comparatively and has the highest manufacturing cost of all.

# %% [markdown]
# ### Shipping and Transportation Analysis

# %%
# Average Revenues generated by shipping carriers
rev_carriers = df.groupby('Shipping carriers', as_index=False)['Revenue generated'].mean()
sns.barplot(data=rev_carriers, x='Shipping carriers', y='Revenue generated', palette='viridis')
plt.title('Average Revenue generated by each Carriers')
plt.show()

# %% [markdown]
# #### We have made most of our revenues by using carrier C.

# %%
# Average cost for each Carrier.
carrier_cost = df.groupby('Shipping carriers', as_index=False)['Total shipping cost'].mean()
sns.barplot(data=carrier_cost, x='Shipping carriers', y='Total shipping cost')
plt.title('Average cost distribution for Shipping carriers')
plt.show()

# %% [markdown]
# #### Revenue and Cost distribution is similar for the Shipping carriers. Carrier C has generated the most average revenue but also has proven to be costliest than others.

# %%
# modes of transportation
trans_modes = df.groupby('Transportation modes').size()
plt.pie(x=trans_modes, labels=trans_modes.index, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# #### Least used transportation mode is by Sea. Other modes are almost used equally.

# %%
# Average Shipping time for each Transporatation method
shipping_time = df.groupby('Transportation modes', as_index=False)['Shipping times'].mean()
sns.barplot(data=shipping_time, x='Transportation modes', y='Shipping times')
plt.title('Shipping Time Taken by Each Transportation Mode')
plt.show()

# %% [markdown]
# #### Fastest shipping was made by Road and Air. Sea transportation is the slowest and hence least used method.

# %%
# Average Cost distribution by transportaion mode
shipping_cost = df.groupby('Transportation modes', as_index=False)['Total shipping cost'].mean()
sns.barplot(data=shipping_cost, x='Transportation modes', y='Total shipping cost')
plt.title('Average Cost Distribution by Transportation mode')
plt.show()

# %% [markdown]
# #### Air and Road methods are the costliest and rail being almost near them. Sea transportation is the cheapest as it is observed to be the slowest.

# %% [markdown]
# ## Suggestions for Improvement

# %% [markdown]
# * **Product Strategy:** Given the popularity and profitability of skincare products, consider focusing on expanding your skincare product line and marketing efforts.
# * **Manufacturing Optimization:** Explore ways to reduce manufacturing costs for haircare products to align them better with their revenue potential.
# * **Customer Segmentation:** Tailor marketing strategies to target "Others," "Females," and non-binary customers who are driving profitability.
# * **Geographical Expansion:** Since Kolkata has the highest customer base, consider expanding marketing and sales efforts in Delhi to tap into that market.
# * **Supplier Relationships:** Strengthen partnerships with Supplier 1 and Supplier 2 due to their cost-effectiveness and contribution to revenue.
# * **Shipping Efficiency:** Evaluate why Carrier C generates the most revenue but is also costlier. Consider optimizing shipping strategies to balance revenue and costs.
# * **Transportation Diversity:** Explore the reasons behind the low usage of sea transportation. Assess if there are scenarios where it could be more cost-effective.tive.
